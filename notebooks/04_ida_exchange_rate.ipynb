# %%
# %cd ..
# Out:
# /home/syed/VS code/globalretail-360

# %%
from src.extract.api_loader import load_exchange_rates

rates_df = load_exchange_rates()
print(rates_df.head())
# Out:
# 2026-02-15 02:03:34 | INFO | src.extract.api_loader | Fetching exchange rates from ExchangeRate API | Base: USD
# 2026-02-15 02:03:34 | INFO | src.extract.api_loader | Exchange rates fetched: 166 currencies
#   currency      rate
# 0      USD    1.0000
# 1      AED    3.6725
# 2      AFN   64.8099
# 3      ALL   81.1101
# 4      AMD  377.4563

# %%
print(rates_df.isna().sum())
# Out:
# currency    0
# rate        0
# dtype: int64
